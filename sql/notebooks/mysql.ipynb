# %%
#tweeter
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

ckey = "mXEtCJeGbCtpiQw0oXWY02Mil"
csecret = "j4w9WayaSu8YftCzaj2Tj7U4b8POw7wb9rfLaNwP2yRzBkYn67"
atoken = "716546342596820992-WumCCtJ586Gk4Ulj0ZEK86vLxNmWoB6"
asecret = "O7w8W48mUeJm96cBLfeJDtCAUXDB9muCdiPwP9yQl7eZ0"

#utils
import json
from datetime import datetime

'''========mysql'=========='''
import pymysql.cursors

connection = pymysql.connect(host='localhost',
                             user='root',
                             db='data',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

def save(tweet):
    created_at,extended_tweet,timestamp_ms,favorite_count,retweet_count,user_mentions,user_name,geo_enabled = tweet.values()

    try:
        with connection.cursor() as cursor:
            # Create table
            create = "CREATE TABLE IF NOT EXISTS `tweets` (`created_at` varchar(50),`extended_tweet` varchar(600),`timestamp_ms` varchar(255) ,`favorite_count` int,`retweet_count` int,`user_mentions` varchar(255), `user_name` varchar(50),`geo_enabled` BOOLEAN);"
            cursor.execute(create)

            # Create a new record
            insert = "INSERT INTO `tweets` (`created_at`, `extended_tweet`, `timestamp_ms`, `favorite_count`, `retweet_count`, `user_mentions`,`user_name`,`geo_enabled`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
            cursor.execute(insert, (created_at,extended_tweet,timestamp_ms,favorite_count,retweet_count,user_mentions,user_name,geo_enabled))

            # connection is not autocommit by default. So you must commit to save
            # your changes.
            connection.commit()

    #         with connection.cursor() as cursor:
    #             # Read a single record
    #             sql = "SELECT * FROM `twitts`"
    #             cursor.execute(sql)
    #             result = cursor.fetchone()
    #             print(result)
    finally:
            print("saved")



def get_date(timestamp):
    date = datetime.fromtimestamp(timestamp/1000.0)
    date = date.strftime('%Y-%m-%d %H:%M:%S')
    return date;

class listener(StreamListener):
    
    def on_data(self, data):
        fields = json.loads(data)
        
        def validate(fields,key):
            if key in fields:
                return fields[key];
            else:
                return None     
        
            
        try:                
            #create data tuple/object/json
            
            tweet = {
                "created_at" : validate(fields,"created_at"),
                "extended_tweet": validate(fields,"extended_tweet")["full_text"] if validate(fields,"extended_tweet") != None else None,
                "timestamp_ms": validate(fields,"timestamp_ms"),
                "favorite_count": validate(fields,"favorite_count"),
                "retweet_count": validate(fields,"retweet_count"),
                "user_mentions": len(validate(fields,"entities")["user_mentions"]) if validate(fields,"entities") != None else 0,
                "user_name": validate(fields,"user")["name"] if validate(fields,"user") != None else None,
                "geo_enabled": validate(fields,"user")["geo_enabled"] if validate(fields,"user") != None else None,
            }
            
            save(tweet);
            print("saved!!")
            print("\n\n")

        except IndexError as e:
            print (e)
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())


twitterStream.filter(track=['covid']);
# Out:
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# saved!!
#
#
#
# saved
# ...
