# %%
#tweeter
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

ckey = "mXEtCJeGbCtpiQw0oXWY02Mil"
csecret = "j4w9WayaSu8YftCzaj2Tj7U4b8POw7wb9rfLaNwP2yRzBkYn67"
atoken = "716546342596820992-WumCCtJ586Gk4Ulj0ZEK86vLxNmWoB6"
asecret = "O7w8W48mUeJm96cBLfeJDtCAUXDB9muCdiPwP9yQl7eZ0"

#utils
import json
from datetime import datetime

'''========mysql'=========='''
import pymysql.cursors

connection = pymysql.connect(host='localhost',
                             user='root',
                             db='data',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

def save(tweet):
    _id,created_at,extended_tweet,timestamp_ms,favorite_count,retweet_count,user_mentions = tweet.values()

    try:
        with connection.cursor() as cursor:
            # Create table
            create = "CREATE TABLE IF NOT EXISTS `tweets` (`id` varchar(600),`created_at` varchar(50),`extended_tweet` varchar(255),`timestamp_ms` varchar(255) ,`favorite_count` int,`retweet_count` int,`user_mentions` int,PRIMARY KEY (`id`));"
            cursor.execute(create)

            # Create a new record
            insert = "INSERT INTO `tweets` (`id`, `created_at`, `extended_tweet`, `timestamp_ms`, `favorite_count`, `retweet_count`, `user_mentions`) VALUES (%s, %s, %s, %s, %s, %s, %s)"
            cursor.execute(insert, (_id,created_at,extended_tweet,timestamp_ms,favorite_count,retweet_count,user_mentions))

            # connection is not autocommit by default. So you must commit to save
            # your changes.
            connection.commit()

    #         with connection.cursor() as cursor:
    #             # Read a single record
    #             sql = "SELECT * FROM `twitts`"
    #             cursor.execute(sql)
    #             result = cursor.fetchone()
    #             print(result)
    finally:
            print("saved")



def get_date(timestamp):
    date = datetime.fromtimestamp(timestamp/1000.0)
    date = date.strftime('%Y-%m-%d %H:%M:%S')
    return date;

class listener(StreamListener):
    
    def on_data(self, data):
        fields = json.loads(data)
        
        def validate(fields,key):
            if key in fields:
                return fields[key];
            else:
                return None     
        
            
        try:                
            #create data tuple/object/json
            
            tweet = {
                "_id" : validate(fields,"id_str") ,
                "created_at" : validate(fields,"created_at"),
                "extended_tweet": validate(fields,"extended_tweet")["full_text"] if validate(fields,"extended_tweet") != None else None,
                "timestamp_ms": validate(fields,"timestamp_ms"),
                "favorite_count": validate(fields,"favorite_count"),
                "retweet_count": validate(fields,"retweet_count"),
                "user_mentions": len(validate(fields,"entities")["user_mentions"]) if validate(fields,"entities") != None else 0
            }
            
            print(type(validate(fields,"created_at")))
            print ("_id :"+str(tweet["_id"])+"\n")
            print ("created_at :"+str(tweet["created_at"])+"\n")
            print ("timestamp_ms :"+str(tweet["timestamp_ms"])+"\n")
            print ("extended_tweet :"+str(tweet["extended_tweet"])+"\n")
            print ("favorite_count :"+str(tweet["favorite_count"])+"\n")
            print ("retweet_count :"+str(tweet["retweet_count"])+"\n")
            print ("user_mentions :"+str(tweet["user_mentions"])+"\n")
            
            save(tweet);
            print("saved!!")
            print("\n\n")

        except IndexError as e:
            print (e)
            pass
        return True
    
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())


twitterStream.filter(track=['covid']);
# Out:
# <class 'str'>
# _id :1306060092622671873
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966161
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060092815691777
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966207
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060092857614337
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966217
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093151207426
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966287
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093276839937
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966317
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093302153222
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966323
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093109264384
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966277
#
# extended_tweet :I do not see that going well...it certainly didn’t for over 200,000 Americans. Despite the scale of this tragedy, we can still do better. #WearAMask
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093411209217
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966349
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093633462272
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966402
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093667115008
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966410
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093717450753
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966422
#
# extended_tweet :@TheRealHoarse Well one son is at college with Covid, and another son is in Pensacola with hurricane Sally. But my husband just got into an argument with Alexa, so I did have a chuckle today.
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093776158720
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966436
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060093926981632
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966472
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094073757701
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966507
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094145085440
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966524
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094237544448
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966546
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094325403648
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966567
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :2
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094489100290
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966606
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094543720448
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966619
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094522753025
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966614
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094442999811
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966595
#
# extended_tweet :Celebrities Join American Lung Association's #Act4Impact Livestream Benefit to Address Impact of COVID-19 in most affected communities https://t.co/JDLbgPk3Hn
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094547795974
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966620
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :2
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094665187331
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966648
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060094702936064
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966657
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :2
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060095055331330
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966741
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :2
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060095349035015
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966811
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060095894233088
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966941
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060095831248896
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966926
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :2
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060096141627393
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967000
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060096120725506
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966995
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060096099803136
#
# created_at :Wed Sep 16 02:39:26 +0000 2020
#
# timestamp_ms :1600223966990
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060096439332870
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967071
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060096884158466
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967177
#
# extended_tweet :Takeaways from the town hall 1) COVID is cancer 2) waiters don’t think people should wear masks 3) all Americans have 401k’s and stock 4) herd mentality will cure COVID
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060096934477825
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967189
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097014169601
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967208
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :2
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097085345792
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967225
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097441927175
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967310
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097488027651
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967321
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097492144130
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967322
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097433538560
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967308
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097559420931
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967338
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097714565127
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967375
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060097735491585
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967380
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
# <class 'str'>
# _id :1306060098150653952
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967479
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060098096128000
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967466
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060098310213634
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967517
#
# extended_tweet :None
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :1
#
# saved
# saved!!
#
#
#
# <class 'str'>
# _id :1306060098146652161
#
# created_at :Wed Sep 16 02:39:27 +0000 2020
#
# timestamp_ms :1600223967478
#
# extended_tweet :#BoycottKBC that Amitabh made a fool of himself the day he got himself admitted in the hospital saying he has COVID &amp; circulating video's from the hospital!! Are you'll still expecting him to stand for TRUTH?Wake up guy's..they open their mouths &amp; full of LIES!! #JusticeForSSR
#
# favorite_count :0
#
# retweet_count :0
#
# user_mentions :0
#
# saved
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-3-3dd14b66971b> in <module>
#     106
#     107
# --> 108 twitterStream.filter(track=['covid']);
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# <ipython-input-3-3dd14b66971b> in on_data(self, data)
#      89             print ("user_mentions :"+str(tweet["user_mentions"])+"\n")
#      90
# ---> 91             save(tweet);
#      92             print("saved!!")
#      93             print("\n\n")
#
# <ipython-input-3-3dd14b66971b> in save(tweet)
#      33             # Create a new record
#      34             insert = "INSERT INTO `tweets` (`id`, `created_at`, `extended_tweet`, `timestamp_ms`, `favorite_count`, `retweet_count`, `user_mentions`) VALUES (%s, %s, %s, %s, %s, %s, %s)"
# ---> 35             cursor.execute(insert, (_id,created_at,extended_tweet,timestamp_ms,favorite_count,retweet_count,user_mentions))
#      36
#      37             # connection is not autocommit by default. So you must commit to save
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# DataError: (1406, "Data too long for column 'extended_tweet' at row 1")
